# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
plt.plot([0,2,3,4,5,6,7,8,9,10,9],'-',[0,3,5,8,4,3,4,4,5,13],'-')
ax2 = fig.add_subplot(2,2,2)
plt.plot([0,2,3,4,5,6,7,8,9,10,0],'-',[0,3,5,8,4,3,4,4,5,13],'-')
ax3 = fig.add_subplot(2,2,3)
plt.plot([0,2,3,4,5,6,7,8,9,10,2],'-',[0,3,5,8,4,3,4,4,5,13],'-')
